# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('99acres_desc.csv')
df.sample(3)
# Out:
#                       name             location  \
# 4331         elite neptune        elite neptune
# 15067           green view                green
# 10585  shafalya the verity  shafalya the verity
#
#                                              description  rate_per_sqft  \
# 4331   a quiet and beautiful apartment located in hea...         4983.0
# 15067  this 3 bhk apartment in shivalik greenview is ...         7280.0
# 10585  the verity offers premium residences with eleg...         8000.0
#
#        area_in_sqft area_type       property_title property_type  bhk_type  \
# 4331         2448.0     super        elite neptune          flat         3
# 15067        2335.0     super           green view          flat         3
# 10585        3800.0     super  shafalya the verity          flat         4
#
#        price_in_cr
# 4331          1.22
# 15067         1.70
# 10585         3.04

# %%
df.drop(columns=['name','property_title'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20060 entries, 0 to 20059
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   location       19765 non-null  object
#  1   description    20045 non-null  object
#  2   rate_per_sqft  19701 non-null  float64
#  3   area_in_sqft   20036 non-null  float64
#  4   area_type      20060 non-null  object
#  5   property_type  20060 non-null  object
#  6   bhk_type       20060 non-null  int64
#  7   price_in_cr    19332 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 1.2+ MB

# %%
df.isnull().mean()*100
# Out:
# location         1.470588
# description      0.074776
# rate_per_sqft    1.789631
# area_in_sqft     0.119641
# area_type        0.000000
# property_type    0.000000
# bhk_type         0.000000
# price_in_cr      3.629113
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df['location']=df['location'].str.split(',').str[0]
df['location'].value_counts().unique()
# Out:
# np.int64(1949)

# %%
top_loc = df['location'].value_counts().nlargest(100).values
top_loc
# Out:
# array([88, 74, 72, 59, 55, 47, 46, 45, 43, 42, 42, 41, 41, 40, 39, 39, 38,
#        38, 38, 37, 37, 37, 37, 36, 36, 35, 35, 34, 34, 34, 32, 32, 31, 31,
#        31, 31, 30, 30, 30, 30, 29, 29, 29, 29, 28, 28, 28, 28, 27, 27, 27,
#        27, 26, 26, 26, 26, 26, 26, 26, 26, 25, 25, 25, 24, 24, 24, 24, 24,
#        24, 24, 23, 23, 23, 23, 23, 23, 23, 23, 23, 22, 22, 22, 22, 22, 22,
#        21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21])
